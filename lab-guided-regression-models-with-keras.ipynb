# %% [markdown]
# <h1> Guided lab: Regression Models with Keras</h1>
#
# Objective for this Notebook
#
# - How to use the Tensorflow API, Keras, to build a regression model.
# - Download and Clean dataset
# - Build a Neural Network
# - Train and Test the Network

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean Dataset</a>
# 2. <a href="#item32">Import Keras</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean Dataset

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %% [markdown]
# ## Data Engineering

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have.

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ## Import Keras

# %% [markdown]
# Recall from the videos that Keras normally runs on top of a low-level library such as TensorFlow. This means that to be able to use the Keras library, you will have to install TensorFlow first and when you import the Keras library, it will be explicitly displayed what backend was used to install the Keras library. In CC Labs, we used TensorFlow as the backend to install Keras, so it should clearly print that when we import Keras.

# %% [markdown]
# #### Let's go ahead and import the Keras library

# %%
from tensorflow import keras

# %% [markdown]
# As you can see, the TensorFlow backend was used to install the Keras library.

# %% [markdown]
# Let's import the rest of the packages from the Keras library that we will need to build our regressoin model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model    
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# <a id='item34'></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()
# Out:
# /opt/anaconda3/envs/ironhack/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Now we will split our data into training and testing with a 70%-30% split (test_size=0.3).
#
# 70% of our data will be used for training :
#
# X_train : Our training data containing the variables the model will use to learn how to predict.
#
# y_train : Our training data containing the labels.
#
# #
# 30% of our data will be used for testing its performance metrics :
#
# X_test : Unseen data by the model, we will use it to make predictions with our trained model.
#
# y_test : The labels associated with X_test data, we will compare them with the predictions that our model provided as output when shown X_test and that way we will obtain performance metrics.

# %%
from sklearn.model_selection import train_test_split
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=42)

# %% [markdown]
# Next, we will train the model using the *fit* method. We will train the model for 100 epochs.

# %%
# fit the model
fit_model = model.fit(X_train, y_train, validation_split=0.2, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 18/18 - 2s - 85ms/step - loss: 1543.7563 - mae: 35.4356 - val_loss: 1515.0891 - val_mae: 35.6559
# Epoch 2/100
# 18/18 - 0s - 4ms/step - loss: 1404.2192 - mae: 33.5490 - val_loss: 1315.7550 - val_mae: 32.8516
# Epoch 3/100
# 18/18 - 0s - 3ms/step - loss: 1092.1870 - mae: 28.7173 - val_loss: 859.2320 - val_mae: 25.4891
# Epoch 4/100
# 18/18 - 0s - 6ms/step - loss: 560.5946 - mae: 19.0682 - val_loss: 316.6004 - val_mae: 14.0990
# Epoch 5/100
# 18/18 - 0s - 4ms/step - loss: 280.5399 - mae: 13.4523 - val_loss: 221.9856 - val_mae: 12.3494
# Epoch 6/100
# 18/18 - 0s - 4ms/step - loss: 247.7908 - mae: 12.6267 - val_loss: 217.3270 - val_mae: 12.2532
# Epoch 7/100
# 18/18 - 0s - 5ms/step - loss: 227.5359 - mae: 12.2300 - val_loss: 205.3490 - val_mae: 11.9900
# Epoch 8/100
# 18/18 - 0s - 5ms/step - loss: 214.4386 - mae: 11.8548 - val_loss: 188.6478 - val_mae: 11.5985
# Epoch 9/100
# 18/18 - 0s - 7ms/step - loss: 204.9961 - mae: 11.6572 - val_loss: 184.9823 - val_mae: 11.4314
# Epoch 10/100
# 18/18 - 0s - 4ms/step - loss: 191.9295 - mae: 11.2941 - val_loss: 173.9788 - val_mae: 11.1803
# Epoch 11/100
# 18/18 - 0s - 3ms/step - loss: 184.0151 - mae: 11.0515 - val_loss: 171.2413 - val_mae: 11.1061
# Epoch 12/100
# 18/18 - 0s - 3ms/step - loss: 175.6229 - mae: 10.8313 - val_loss: 163.7379 - val_mae: 10.8538
# Epoch 13/100
# 18/18 - 0s - 5ms/step - loss: 169.5274 - mae: 10.6002 - val_loss: 159.3381 - val_mae: 10.7120
# Epoch 14/100
# 18/18 - 0s - 3ms/step - loss: 162.9487 - mae: 10.3858 - val_loss: 157.1223 - val_mae: 10.6140
# Epoch 15/100
# 18/18 - 0s - 3ms/step - loss: 156.7082 - mae: 10.1975 - val_loss: 148.8624 - val_mae: 10.3433
# Epoch 16/100
# 18/18 - 0s - 3ms/step - loss: 151.5060 - mae: 10.0416 - val_loss: 145.8308 - val_mae: 10.2256
# Epoch 17/100
# 18/18 - 0s - 12ms/step - loss: 147.4198 - mae: 9.9038 - val_loss: 143.4471 - val_mae: 10.1444
# Epoch 18/100
# 18/18 - 0s - 3ms/step - loss: 141.7204 - mae: 9.6749 - val_loss: 140.1034 - val_mae: 9.9708
# Epoch 19/100
# 18/18 - 0s - 3ms/step - loss: 136.4954 - mae: 9.4534 - val_loss: 135.0917 - val_mae: 9.7650
# Epoch 20/100
# 18/18 - 0s - 4ms/step - loss: 131.1811 - mae: 9.2671 - val_loss: 132.6962 - val_mae: 9.6639
# Epoch 21/100
# 18/18 - 0s - 4ms/step - loss: 126.2115 - mae: 9.0761 - val_loss: 129.4191 - val_mae: 9.5100
# Epoch 22/100
# 18/18 - 0s - 3ms/step - loss: 121.8118 - mae: 8.8750 - val_loss: 127.1607 - val_mae: 9.3755
# Epoch 23/100
# 18/18 - 0s - 8ms/step - loss: 116.0168 - mae: 8.6646 - val_loss: 127.4674 - val_mae: 9.3768
# Epoch 24/100
# 18/18 - 0s - 3ms/step - loss: 111.6712 - mae: 8.4854 - val_loss: 121.2256 - val_mae: 9.0813
# Epoch 25/100
# 18/18 - 0s - 4ms/step - loss: 106.0307 - mae: 8.2097 - val_loss: 116.2394 - val_mae: 8.8504
# Epoch 26/100
# 18/18 - 0s - 4ms/step - loss: 101.2356 - mae: 7.9906 - val_loss: 112.8975 - val_mae: 8.6893
# Epoch 27/100
# 18/18 - 0s - 3ms/step - loss: 96.9853 - mae: 7.7861 - val_loss: 112.6234 - val_mae: 8.6866
# Epoch 28/100
# 18/18 - 0s - 3ms/step - loss: 92.8476 - mae: 7.5651 - val_loss: 106.3032 - val_mae: 8.3679
# Epoch 29/100
# 18/18 - 0s - 3ms/step - loss: 89.2005 - mae: 7.3551 - val_loss: 107.4450 - val_mae: 8.3893
# Epoch 30/100
# 18/18 - 0s - 7ms/step - loss: 85.3742 - mae: 7.1890 - val_loss: 99.2998 - val_mae: 7.9524
# Epoch 31/100
# 18/18 - 0s - 3ms/step - loss: 81.8027 - mae: 7.0076 - val_loss: 97.6672 - val_mae: 7.8799
# Epoch 32/100
# 18/18 - 0s - 7ms/step - loss: 79.1725 - mae: 6.8341 - val_loss: 97.1983 - val_mae: 7.8911
# Epoch 33/100
# 18/18 - 0s - 3ms/step - loss: 75.2421 - mae: 6.6574 - val_loss: 94.0152 - val_mae: 7.6866
# Epoch 34/100
# 18/18 - 0s - 4ms/step - loss: 72.7598 - mae: 6.5320 - val_loss: 88.9496 - val_mae: 7.4486
# Epoch 35/100
# 18/18 - 0s - 6ms/step - loss: 71.6340 - mae: 6.4584 - val_loss: 88.9750 - val_mae: 7.5094
# Epoch 36/100
# 18/18 - 0s - 3ms/step - loss: 68.2754 - mae: 6.2505 - val_loss: 87.5822 - val_mae: 7.4082
# Epoch 37/100
# 18/18 - 0s - 3ms/step - loss: 66.3897 - mae: 6.1594 - val_loss: 85.7823 - val_mae: 7.3704
# Epoch 38/100
# 18/18 - 0s - 3ms/step - loss: 64.4088 - mae: 6.0141 - val_loss: 81.6096 - val_mae: 7.1930
# Epoch 39/100
# 18/18 - 0s - 3ms/step - loss: 62.3166 - mae: 5.9474 - val_loss: 80.6129 - val_mae: 7.0977
# Epoch 40/100
# 18/18 - 0s - 3ms/step - loss: 60.9551 - mae: 5.8573 - val_loss: 78.3649 - val_mae: 6.9858
# Epoch 41/100
# 18/18 - 0s - 6ms/step - loss: 60.2037 - mae: 5.7708 - val_loss: 79.2717 - val_mae: 7.1008
# Epoch 42/100
# 18/18 - 0s - 3ms/step - loss: 58.4337 - mae: 5.7336 - val_loss: 75.9335 - val_mae: 6.9014
# Epoch 43/100
# 18/18 - 0s - 3ms/step - loss: 57.3021 - mae: 5.6312 - val_loss: 73.5853 - val_mae: 6.7626
# Epoch 44/100
# 18/18 - 0s - 3ms/step - loss: 55.8366 - mae: 5.5896 - val_loss: 74.6536 - val_mae: 6.8769
# Epoch 45/100
# 18/18 - 0s - 10ms/step - loss: 55.7627 - mae: 5.5714 - val_loss: 69.8653 - val_mae: 6.6033
# Epoch 46/100
# 18/18 - 0s - 6ms/step - loss: 54.0838 - mae: 5.5201 - val_loss: 69.3879 - val_mae: 6.5385
# Epoch 47/100
# 18/18 - 0s - 3ms/step - loss: 52.2116 - mae: 5.4043 - val_loss: 67.8832 - val_mae: 6.4847
# Epoch 48/100
# 18/18 - 0s - 4ms/step - loss: 51.1826 - mae: 5.3538 - val_loss: 68.2124 - val_mae: 6.5655
# Epoch 49/100
# 18/18 - 0s - 3ms/step - loss: 49.3092 - mae: 5.2138 - val_loss: 64.4223 - val_mae: 6.2775
# Epoch 50/100
# 18/18 - 0s - 3ms/step - loss: 48.2109 - mae: 5.1352 - val_loss: 64.0247 - val_mae: 6.3110
# Epoch 51/100
# 18/18 - 0s - 6ms/step - loss: 47.5650 - mae: 5.0873 - val_loss: 63.2546 - val_mae: 6.2494
# Epoch 52/100
# 18/18 - 0s - 3ms/step - loss: 46.3445 - mae: 5.0746 - val_loss: 60.3157 - val_mae: 6.0903
# Epoch 53/100
# 18/18 - 0s - 3ms/step - loss: 46.2172 - mae: 5.0684 - val_loss: 60.0261 - val_mae: 6.0481
# Epoch 54/100
# 18/18 - 0s - 3ms/step - loss: 44.6694 - mae: 4.9726 - val_loss: 59.5198 - val_mae: 6.0146
# Epoch 55/100
# 18/18 - 0s - 5ms/step - loss: 43.8516 - mae: 4.9125 - val_loss: 57.9313 - val_mae: 5.9119
# Epoch 56/100
# 18/18 - 0s - 4ms/step - loss: 42.3380 - mae: 4.8061 - val_loss: 56.5819 - val_mae: 5.8231
# Epoch 57/100
# 18/18 - 0s - 10ms/step - loss: 41.4656 - mae: 4.7710 - val_loss: 56.7920 - val_mae: 5.8494
# Epoch 58/100
# 18/18 - 0s - 6ms/step - loss: 41.3385 - mae: 4.7772 - val_loss: 55.9060 - val_mae: 5.8011
# Epoch 59/100
# 18/18 - 0s - 3ms/step - loss: 40.5238 - mae: 4.7481 - val_loss: 54.9863 - val_mae: 5.7240
# Epoch 60/100
# 18/18 - 0s - 3ms/step - loss: 40.2807 - mae: 4.7115 - val_loss: 55.7005 - val_mae: 5.7236
# Epoch 61/100
# 18/18 - 0s - 3ms/step - loss: 39.5175 - mae: 4.6407 - val_loss: 53.6329 - val_mae: 5.6748
# Epoch 62/100
# 18/18 - 0s - 5ms/step - loss: 39.0112 - mae: 4.6396 - val_loss: 54.0630 - val_mae: 5.6334
# Epoch 63/100
# 18/18 - 0s - 10ms/step - loss: 39.3222 - mae: 4.6747 - val_loss: 52.5762 - val_mae: 5.5851
# Epoch 64/100
# 18/18 - 0s - 4ms/step - loss: 38.3582 - mae: 4.6268 - val_loss: 51.6636 - val_mae: 5.5493
# Epoch 65/100
# 18/18 - 0s - 4ms/step - loss: 36.5456 - mae: 4.5120 - val_loss: 51.1954 - val_mae: 5.4818
# Epoch 66/100
# 18/18 - 0s - 4ms/step - loss: 35.8707 - mae: 4.4654 - val_loss: 49.6881 - val_mae: 5.4008
# Epoch 67/100
# 18/18 - 0s - 3ms/step - loss: 35.6714 - mae: 4.4446 - val_loss: 50.2072 - val_mae: 5.3745
# Epoch 68/100
# 18/18 - 0s - 4ms/step - loss: 34.8835 - mae: 4.3898 - val_loss: 48.9130 - val_mae: 5.3037
# Epoch 69/100
# 18/18 - 0s - 7ms/step - loss: 34.7164 - mae: 4.3858 - val_loss: 48.4059 - val_mae: 5.2834
# Epoch 70/100
# 18/18 - 0s - 3ms/step - loss: 34.3589 - mae: 4.4103 - val_loss: 49.2159 - val_mae: 5.3355
# Epoch 71/100
# 18/18 - 0s - 4ms/step - loss: 33.3607 - mae: 4.3228 - val_loss: 49.5636 - val_mae: 5.3219
# Epoch 72/100
# 18/18 - 0s - 3ms/step - loss: 34.3504 - mae: 4.3889 - val_loss: 48.7072 - val_mae: 5.2292
# Epoch 73/100
# 18/18 - 0s - 3ms/step - loss: 34.2443 - mae: 4.3401 - val_loss: 47.2311 - val_mae: 5.1938
# Epoch 74/100
# 18/18 - 0s - 4ms/step - loss: 32.5466 - mae: 4.2744 - val_loss: 47.2289 - val_mae: 5.1226
# Epoch 75/100
# 18/18 - 0s - 7ms/step - loss: 31.7414 - mae: 4.1911 - val_loss: 46.8310 - val_mae: 5.1248
# Epoch 76/100
# 18/18 - 0s - 3ms/step - loss: 32.6124 - mae: 4.2848 - val_loss: 47.4983 - val_mae: 5.1677
# Epoch 77/100
# 18/18 - 0s - 4ms/step - loss: 32.2421 - mae: 4.2280 - val_loss: 45.9709 - val_mae: 5.0787
# Epoch 78/100
# 18/18 - 0s - 3ms/step - loss: 31.5284 - mae: 4.2115 - val_loss: 45.8685 - val_mae: 5.0631
# Epoch 79/100
# 18/18 - 0s - 4ms/step - loss: 30.7198 - mae: 4.1428 - val_loss: 47.4670 - val_mae: 5.1914
# Epoch 80/100
# 18/18 - 0s - 12ms/step - loss: 31.3497 - mae: 4.1481 - val_loss: 45.3440 - val_mae: 5.0156
# Epoch 81/100
# 18/18 - 0s - 4ms/step - loss: 30.9792 - mae: 4.1956 - val_loss: 44.9069 - val_mae: 4.9516
# Epoch 82/100
# 18/18 - 0s - 5ms/step - loss: 30.4092 - mae: 4.0797 - val_loss: 45.5748 - val_mae: 5.0519
# Epoch 83/100
# 18/18 - 0s - 4ms/step - loss: 30.3926 - mae: 4.1555 - val_loss: 45.4711 - val_mae: 4.9903
# Epoch 84/100
# 18/18 - 0s - 4ms/step - loss: 30.4139 - mae: 4.0866 - val_loss: 47.2132 - val_mae: 5.1462
# Epoch 85/100
# 18/18 - 0s - 8ms/step - loss: 31.3650 - mae: 4.2167 - val_loss: 44.9345 - val_mae: 4.9524
# Epoch 86/100
# 18/18 - 0s - 4ms/step - loss: 29.6510 - mae: 4.0340 - val_loss: 46.1129 - val_mae: 5.1027
# Epoch 87/100
# 18/18 - 0s - 3ms/step - loss: 29.4098 - mae: 4.0231 - val_loss: 44.4479 - val_mae: 4.9179
# Epoch 88/100
# 18/18 - 0s - 5ms/step - loss: 28.3167 - mae: 3.9584 - val_loss: 44.2600 - val_mae: 4.9075
# Epoch 89/100
# 18/18 - 0s - 3ms/step - loss: 28.2704 - mae: 3.9307 - val_loss: 43.7522 - val_mae: 4.8651
# Epoch 90/100
# 18/18 - 0s - 4ms/step - loss: 28.5758 - mae: 4.0095 - val_loss: 47.6349 - val_mae: 5.1431
# Epoch 91/100
# 18/18 - 0s - 6ms/step - loss: 31.4486 - mae: 4.1857 - val_loss: 47.2607 - val_mae: 5.1716
# Epoch 92/100
# 18/18 - 0s - 3ms/step - loss: 28.9466 - mae: 3.9829 - val_loss: 44.5653 - val_mae: 4.9638
# Epoch 93/100
# 18/18 - 0s - 3ms/step - loss: 27.8586 - mae: 3.9228 - val_loss: 44.2936 - val_mae: 4.9655
# Epoch 94/100
# 18/18 - 0s - 3ms/step - loss: 28.0056 - mae: 3.9335 - val_loss: 44.2526 - val_mae: 4.8712
# Epoch 95/100
# 18/18 - 0s - 3ms/step - loss: 28.0244 - mae: 3.9067 - val_loss: 41.8989 - val_mae: 4.7566
# Epoch 96/100
# 18/18 - 0s - 3ms/step - loss: 26.4933 - mae: 3.8393 - val_loss: 43.5198 - val_mae: 4.8405
# Epoch 97/100
# 18/18 - 0s - 6ms/step - loss: 26.5384 - mae: 3.8518 - val_loss: 42.7355 - val_mae: 4.7932
# Epoch 98/100
# 18/18 - 0s - 3ms/step - loss: 26.3462 - mae: 3.7925 - val_loss: 42.3653 - val_mae: 4.7657
# Epoch 99/100
# 18/18 - 0s - 8ms/step - loss: 25.7276 - mae: 3.7698 - val_loss: 42.0684 - val_mae: 4.7708
# Epoch 100/100
# 18/18 - 0s - 3ms/step - loss: 25.5983 - mae: 3.7666 - val_loss: 41.8197 - val_mae: 4.7381

# %% [markdown]
# ### Now lets evaluate our model and get performance metrics !
#
# First, since our model only saw the training data and learned from it, we will make predictions on the unseen test set.
#
# y_pred are the predictions that our model generated from it's experience when shown the predictor variables of X_test.
#
# That way we can compare y_pred (predictions made by our model) with y_test (the real labels of X_test) and see the difference as performance metrics.

# %%
import matplotlib.pyplot as plt

plt.plot(fit_model.history['loss'], label='Training Loss')
plt.plot(fit_model.history['val_loss'], label='Validation Loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss vs Validation Loss')
plt.legend()
plt.show()

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# Since this is a regression model we will be using mean squared error, mean absolute error and the r squared score to evaluate it.

# %%
# Calculate and print regression metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Mean Absolute Error (MAE): {mae:.4f}')
print(f'R² Score: {r2:.4f}')
# Out:
# Mean Squared Error (MSE): 47.8229
# Mean Absolute Error (MAE): 5.0965
# R² Score: 0.8233

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# For other models, other types of performance metrics are more meaningfull. It all depends on context and the end goal of the model.
#
# Research, planning and analysing various metrics with a clearly defined end goal is key to understanding how capable a model is and what are his limitations.
#
# Keep that in mind when tackling the next exercises!

# %% [markdown]
# ### Thank you for following this tutorial!
