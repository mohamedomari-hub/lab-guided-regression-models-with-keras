# %% [markdown]
# <h1> Guided lab: Regression Models with Keras</h1>
#
# Objective for this Notebook
#
# - How to use the Tensorflow API, Keras, to build a regression model.
# - Download and Clean dataset
# - Build a Neural Network
# - Train and Test the Network

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean Dataset</a>
# 2. <a href="#item32">Import Keras</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean Dataset

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have.

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ## Import Keras

# %% [markdown]
# Recall from the videos that Keras normally runs on top of a low-level library such as TensorFlow. This means that to be able to use the Keras library, you will have to install TensorFlow first and when you import the Keras library, it will be explicitly displayed what backend was used to install the Keras library. In CC Labs, we used TensorFlow as the backend to install Keras, so it should clearly print that when we import Keras.

# %% [markdown]
# #### Let's go ahead and import the Keras library

# %%
from tensorflow import keras

# %% [markdown]
# As you can see, the TensorFlow backend was used to install the Keras library.

# %% [markdown]
# Let's import the rest of the packages from the Keras library that we will need to build our regressoin model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model    
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# <a id='item34'></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()
# Out:
# /opt/anaconda3/envs/ironhack/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Now we will split our data into training and testing with a 70%-30% split (test_size=0.3).
#
# 70% of our data will be used for training :
#
# X_train : Our training data containing the variables the model will use to learn how to predict.
#
# y_train : Our training data containing the labels.
#
# #
# 30% of our data will be used for testing its performance metrics :
#
# X_test : Unseen data by the model, we will use it to make predictions with our trained model.
#
# y_test : The labels associated with X_test data, we will compare them with the predictions that our model provided as output when shown X_test and that way we will obtain performance metrics.

# %%
from sklearn.model_selection import train_test_split
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=42)

# %% [markdown]
# Next, we will train the model using the *fit* method. We will train the model for 100 epochs.

# %%
# fit the model
fit_model = model.fit(X_train, y_train, validation_split=0.2, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 18/18 - 1s - 77ms/step - loss: 1543.4352 - mae: 35.4462 - val_loss: 1502.0862 - val_mae: 35.4761
# Epoch 2/100
# 18/18 - 0s - 4ms/step - loss: 1286.7466 - mae: 31.7503 - val_loss: 996.1530 - val_mae: 27.9651
# Epoch 3/100
# 18/18 - 0s - 3ms/step - loss: 474.6644 - mae: 17.2677 - val_loss: 216.8282 - val_mae: 11.8945
# Epoch 4/100
# 18/18 - 0s - 5ms/step - loss: 270.4893 - mae: 13.0870 - val_loss: 254.1841 - val_mae: 13.0148
# Epoch 5/100
# 18/18 - 0s - 5ms/step - loss: 226.6556 - mae: 12.2771 - val_loss: 171.6804 - val_mae: 10.9312
# Epoch 6/100
# 18/18 - 0s - 3ms/step - loss: 202.7130 - mae: 11.6446 - val_loss: 177.5387 - val_mae: 11.1163
# Epoch 7/100
# 18/18 - 0s - 3ms/step - loss: 189.2439 - mae: 11.2715 - val_loss: 161.9307 - val_mae: 10.6535
# Epoch 8/100
# 18/18 - 0s - 3ms/step - loss: 180.3315 - mae: 10.9668 - val_loss: 160.4633 - val_mae: 10.6008
# Epoch 9/100
# 18/18 - 0s - 2ms/step - loss: 173.4980 - mae: 10.7413 - val_loss: 157.2457 - val_mae: 10.4672
# Epoch 10/100
# 18/18 - 0s - 3ms/step - loss: 168.5732 - mae: 10.5930 - val_loss: 146.9031 - val_mae: 10.1181
# Epoch 11/100
# 18/18 - 0s - 3ms/step - loss: 160.8324 - mae: 10.3326 - val_loss: 144.4626 - val_mae: 10.0839
# Epoch 12/100
# 18/18 - 0s - 4ms/step - loss: 156.8353 - mae: 10.1950 - val_loss: 146.0893 - val_mae: 10.0808
# Epoch 13/100
# 18/18 - 0s - 3ms/step - loss: 148.9675 - mae: 9.8841 - val_loss: 139.1190 - val_mae: 9.8865
# Epoch 14/100
# 18/18 - 0s - 3ms/step - loss: 144.7399 - mae: 9.7155 - val_loss: 145.3010 - val_mae: 10.0851
# Epoch 15/100
# 18/18 - 0s - 3ms/step - loss: 137.9629 - mae: 9.4647 - val_loss: 127.2318 - val_mae: 9.3007
# Epoch 16/100
# 18/18 - 0s - 3ms/step - loss: 131.1725 - mae: 9.2577 - val_loss: 126.8948 - val_mae: 9.4089
# Epoch 17/100
# 18/18 - 0s - 3ms/step - loss: 123.4869 - mae: 8.8831 - val_loss: 117.0727 - val_mae: 8.8127
# Epoch 18/100
# 18/18 - 0s - 3ms/step - loss: 118.4548 - mae: 8.7389 - val_loss: 111.5434 - val_mae: 8.5569
# Epoch 19/100
# 18/18 - 0s - 3ms/step - loss: 114.1248 - mae: 8.4560 - val_loss: 111.6593 - val_mae: 8.7348
# Epoch 20/100
# 18/18 - 0s - 3ms/step - loss: 102.3127 - mae: 8.0071 - val_loss: 101.5468 - val_mae: 8.1014
# Epoch 21/100
# 18/18 - 0s - 3ms/step - loss: 96.1871 - mae: 7.7365 - val_loss: 94.4754 - val_mae: 7.7561
# Epoch 22/100
# 18/18 - 0s - 3ms/step - loss: 90.2317 - mae: 7.4983 - val_loss: 94.7319 - val_mae: 7.8338
# Epoch 23/100
# 18/18 - 0s - 3ms/step - loss: 86.4415 - mae: 7.2375 - val_loss: 85.8910 - val_mae: 7.3513
# Epoch 24/100
# 18/18 - 0s - 3ms/step - loss: 75.7106 - mae: 6.7364 - val_loss: 78.1977 - val_mae: 6.9646
# Epoch 25/100
# 18/18 - 0s - 3ms/step - loss: 69.1948 - mae: 6.5103 - val_loss: 73.8368 - val_mae: 6.7443
# Epoch 26/100
# 18/18 - 0s - 9ms/step - loss: 63.2654 - mae: 6.1724 - val_loss: 67.3329 - val_mae: 6.3398
# Epoch 27/100
# 18/18 - 0s - 3ms/step - loss: 59.2145 - mae: 5.9844 - val_loss: 63.3968 - val_mae: 6.1131
# Epoch 28/100
# 18/18 - 0s - 3ms/step - loss: 52.5180 - mae: 5.5419 - val_loss: 61.6323 - val_mae: 5.9556
# Epoch 29/100
# 18/18 - 0s - 3ms/step - loss: 49.8070 - mae: 5.3264 - val_loss: 59.4902 - val_mae: 5.7965
# Epoch 30/100
# 18/18 - 0s - 3ms/step - loss: 48.7795 - mae: 5.2820 - val_loss: 62.5327 - val_mae: 5.9291
# Epoch 31/100
# 18/18 - 0s - 3ms/step - loss: 44.1017 - mae: 4.9297 - val_loss: 55.7764 - val_mae: 5.5975
# Epoch 32/100
# 18/18 - 0s - 3ms/step - loss: 42.1611 - mae: 4.8980 - val_loss: 55.2151 - val_mae: 5.5206
# Epoch 33/100
# 18/18 - 0s - 3ms/step - loss: 41.3146 - mae: 4.8039 - val_loss: 54.3954 - val_mae: 5.4946
# Epoch 34/100
# 18/18 - 0s - 2ms/step - loss: 38.3414 - mae: 4.6502 - val_loss: 50.6678 - val_mae: 5.2451
# Epoch 35/100
# 18/18 - 0s - 2ms/step - loss: 36.5985 - mae: 4.5427 - val_loss: 53.5717 - val_mae: 5.5330
# Epoch 36/100
# 18/18 - 0s - 2ms/step - loss: 37.4738 - mae: 4.5337 - val_loss: 49.5930 - val_mae: 5.2549
# Epoch 37/100
# 18/18 - 0s - 2ms/step - loss: 35.6721 - mae: 4.4493 - val_loss: 49.8990 - val_mae: 5.2684
# Epoch 38/100
# 18/18 - 0s - 3ms/step - loss: 32.3849 - mae: 4.2105 - val_loss: 48.9780 - val_mae: 5.2309
# Epoch 39/100
# 18/18 - 0s - 3ms/step - loss: 30.8521 - mae: 4.1500 - val_loss: 46.4483 - val_mae: 5.0774
# Epoch 40/100
# 18/18 - 0s - 3ms/step - loss: 30.6933 - mae: 4.1487 - val_loss: 45.0923 - val_mae: 4.9773
# Epoch 41/100
# 18/18 - 0s - 3ms/step - loss: 29.5298 - mae: 3.9639 - val_loss: 44.4132 - val_mae: 4.9649
# Epoch 42/100
# 18/18 - 0s - 3ms/step - loss: 27.5909 - mae: 3.9499 - val_loss: 44.3297 - val_mae: 4.9327
# Epoch 43/100
# 18/18 - 0s - 3ms/step - loss: 27.8844 - mae: 3.9488 - val_loss: 47.7827 - val_mae: 5.2522
# Epoch 44/100
# 18/18 - 0s - 3ms/step - loss: 27.8247 - mae: 3.9526 - val_loss: 44.2293 - val_mae: 4.9750
# Epoch 45/100
# 18/18 - 0s - 3ms/step - loss: 25.6503 - mae: 3.7820 - val_loss: 43.4299 - val_mae: 4.9295
# Epoch 46/100
# 18/18 - 0s - 3ms/step - loss: 24.9554 - mae: 3.7197 - val_loss: 41.8408 - val_mae: 4.8630
# Epoch 47/100
# 18/18 - 0s - 3ms/step - loss: 26.1723 - mae: 3.7981 - val_loss: 41.9394 - val_mae: 4.9240
# Epoch 48/100
# 18/18 - 0s - 3ms/step - loss: 24.4431 - mae: 3.6382 - val_loss: 45.5275 - val_mae: 5.0461
# Epoch 49/100
# 18/18 - 0s - 3ms/step - loss: 24.8634 - mae: 3.7754 - val_loss: 41.6143 - val_mae: 4.8851
# Epoch 50/100
# 18/18 - 0s - 7ms/step - loss: 24.4874 - mae: 3.6977 - val_loss: 41.6335 - val_mae: 4.8833
# Epoch 51/100
# 18/18 - 0s - 3ms/step - loss: 22.9465 - mae: 3.5340 - val_loss: 40.8612 - val_mae: 4.8499
# Epoch 52/100
# 18/18 - 0s - 3ms/step - loss: 22.4291 - mae: 3.5284 - val_loss: 41.5806 - val_mae: 4.8695
# Epoch 53/100
# 18/18 - 0s - 3ms/step - loss: 22.2263 - mae: 3.4888 - val_loss: 41.9311 - val_mae: 4.8844
# Epoch 54/100
# 18/18 - 0s - 3ms/step - loss: 21.3376 - mae: 3.4269 - val_loss: 40.7100 - val_mae: 4.7869
# Epoch 55/100
# 18/18 - 0s - 2ms/step - loss: 20.7756 - mae: 3.3933 - val_loss: 41.5258 - val_mae: 4.8722
# Epoch 56/100
# 18/18 - 0s - 2ms/step - loss: 21.0092 - mae: 3.4250 - val_loss: 40.6087 - val_mae: 4.8029
# Epoch 57/100
# 18/18 - 0s - 2ms/step - loss: 20.2521 - mae: 3.3565 - val_loss: 40.8519 - val_mae: 4.8436
# Epoch 58/100
# 18/18 - 0s - 2ms/step - loss: 20.2409 - mae: 3.3012 - val_loss: 43.9313 - val_mae: 4.9394
# Epoch 59/100
# 18/18 - 0s - 2ms/step - loss: 21.7051 - mae: 3.5489 - val_loss: 40.4922 - val_mae: 4.7299
# Epoch 60/100
# 18/18 - 0s - 2ms/step - loss: 20.6857 - mae: 3.3515 - val_loss: 40.9254 - val_mae: 4.8111
# Epoch 61/100
# 18/18 - 0s - 4ms/step - loss: 19.4387 - mae: 3.2707 - val_loss: 39.9268 - val_mae: 4.7843
# Epoch 62/100
# 18/18 - 0s - 3ms/step - loss: 19.4740 - mae: 3.2597 - val_loss: 39.4769 - val_mae: 4.7637
# Epoch 63/100
# 18/18 - 0s - 3ms/step - loss: 18.9748 - mae: 3.2269 - val_loss: 40.1625 - val_mae: 4.7417
# Epoch 64/100
# 18/18 - 0s - 3ms/step - loss: 18.6576 - mae: 3.1843 - val_loss: 39.9957 - val_mae: 4.8101
# Epoch 65/100
# 18/18 - 0s - 2ms/step - loss: 17.5651 - mae: 3.1737 - val_loss: 38.5718 - val_mae: 4.6928
# Epoch 66/100
# 18/18 - 0s - 2ms/step - loss: 17.8308 - mae: 3.1118 - val_loss: 40.0224 - val_mae: 4.7794
# Epoch 67/100
# 18/18 - 0s - 2ms/step - loss: 17.6231 - mae: 3.1105 - val_loss: 40.0102 - val_mae: 4.8051
# Epoch 68/100
# 18/18 - 0s - 3ms/step - loss: 17.7686 - mae: 3.1616 - val_loss: 38.3269 - val_mae: 4.7483
# Epoch 69/100
# 18/18 - 0s - 3ms/step - loss: 17.9770 - mae: 3.1903 - val_loss: 42.0834 - val_mae: 4.9116
# Epoch 70/100
# 18/18 - 0s - 2ms/step - loss: 19.1398 - mae: 3.2925 - val_loss: 40.4507 - val_mae: 4.7764
# Epoch 71/100
# 18/18 - 0s - 2ms/step - loss: 18.6560 - mae: 3.2296 - val_loss: 37.1531 - val_mae: 4.6300
# Epoch 72/100
# 18/18 - 0s - 2ms/step - loss: 16.8910 - mae: 3.0763 - val_loss: 39.6335 - val_mae: 4.7790
# Epoch 73/100
# 18/18 - 0s - 2ms/step - loss: 16.9949 - mae: 3.0715 - val_loss: 38.3296 - val_mae: 4.6889
# Epoch 74/100
# 18/18 - 0s - 2ms/step - loss: 16.0528 - mae: 2.9962 - val_loss: 39.5806 - val_mae: 4.7747
# Epoch 75/100
# 18/18 - 0s - 2ms/step - loss: 16.2322 - mae: 3.0449 - val_loss: 39.8683 - val_mae: 4.7785
# Epoch 76/100
# 18/18 - 0s - 2ms/step - loss: 16.3494 - mae: 3.0192 - val_loss: 37.6142 - val_mae: 4.6263
# Epoch 77/100
# 18/18 - 0s - 2ms/step - loss: 15.8236 - mae: 2.9795 - val_loss: 36.6882 - val_mae: 4.5598
# Epoch 78/100
# 18/18 - 0s - 2ms/step - loss: 15.7031 - mae: 3.0144 - val_loss: 38.6504 - val_mae: 4.7065
# Epoch 79/100
# 18/18 - 0s - 2ms/step - loss: 15.9620 - mae: 2.9788 - val_loss: 38.3014 - val_mae: 4.6630
# Epoch 80/100
# 18/18 - 0s - 2ms/step - loss: 16.7724 - mae: 3.1343 - val_loss: 36.5195 - val_mae: 4.5478
# Epoch 81/100
# 18/18 - 0s - 2ms/step - loss: 17.8331 - mae: 3.1624 - val_loss: 38.7699 - val_mae: 4.7520
# Epoch 82/100
# 18/18 - 0s - 2ms/step - loss: 14.5868 - mae: 2.8435 - val_loss: 38.0029 - val_mae: 4.6577
# Epoch 83/100
# 18/18 - 0s - 2ms/step - loss: 14.3087 - mae: 2.8140 - val_loss: 36.8195 - val_mae: 4.5763
# Epoch 84/100
# 18/18 - 0s - 2ms/step - loss: 14.2242 - mae: 2.8086 - val_loss: 39.5623 - val_mae: 4.7387
# Epoch 85/100
# 18/18 - 0s - 2ms/step - loss: 15.1843 - mae: 2.9243 - val_loss: 36.7120 - val_mae: 4.6047
# Epoch 86/100
# 18/18 - 0s - 2ms/step - loss: 14.0415 - mae: 2.7589 - val_loss: 38.5081 - val_mae: 4.6790
# Epoch 87/100
# 18/18 - 0s - 2ms/step - loss: 14.0804 - mae: 2.8534 - val_loss: 37.7354 - val_mae: 4.6676
# Epoch 88/100
# 18/18 - 0s - 2ms/step - loss: 15.0257 - mae: 2.8940 - val_loss: 40.4166 - val_mae: 4.8259
# Epoch 89/100
# 18/18 - 0s - 2ms/step - loss: 13.5516 - mae: 2.7181 - val_loss: 36.8686 - val_mae: 4.5618
# Epoch 90/100
# 18/18 - 0s - 2ms/step - loss: 13.1640 - mae: 2.7159 - val_loss: 39.9068 - val_mae: 4.8180
# Epoch 91/100
# 18/18 - 0s - 3ms/step - loss: 13.4967 - mae: 2.7544 - val_loss: 37.3715 - val_mae: 4.5689
# Epoch 92/100
# 18/18 - 0s - 2ms/step - loss: 13.0411 - mae: 2.6986 - val_loss: 38.1638 - val_mae: 4.6253
# Epoch 93/100
# 18/18 - 0s - 5ms/step - loss: 14.2968 - mae: 2.7930 - val_loss: 36.5577 - val_mae: 4.5401
# Epoch 94/100
# 18/18 - 0s - 2ms/step - loss: 15.1026 - mae: 2.8969 - val_loss: 40.2428 - val_mae: 4.7500
# Epoch 95/100
# 18/18 - 0s - 2ms/step - loss: 13.9897 - mae: 2.8395 - val_loss: 39.0009 - val_mae: 4.6715
# Epoch 96/100
# 18/18 - 0s - 2ms/step - loss: 12.9823 - mae: 2.7109 - val_loss: 37.3619 - val_mae: 4.6715
# Epoch 97/100
# 18/18 - 0s - 2ms/step - loss: 12.9126 - mae: 2.6716 - val_loss: 37.3232 - val_mae: 4.5399
# Epoch 98/100
# 18/18 - 0s - 2ms/step - loss: 12.8158 - mae: 2.6188 - val_loss: 37.1056 - val_mae: 4.6169
# Epoch 99/100
# 18/18 - 0s - 2ms/step - loss: 13.4713 - mae: 2.7439 - val_loss: 37.7117 - val_mae: 4.5850
# Epoch 100/100
# 18/18 - 0s - 2ms/step - loss: 13.2263 - mae: 2.6955 - val_loss: 38.4534 - val_mae: 4.6567

# %% [markdown]
# ### Now lets evaluate our model and get performance metrics !
#
# First, since our model only saw the training data and learned from it, we will make predictions on the unseen test set.
#
# y_pred are the predictions that our model generated from it's experience when shown the predictor variables of X_test.
#
# That way we can compare y_pred (predictions made by our model) with y_test (the real labels of X_test) and see the difference as performance metrics.

# %%
import matplotlib.pyplot as plt

plt.plot(fit_model.history['loss'], label='Training Loss')
plt.plot(fit_model.history['val_loss'], label='Validation Loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss vs Validation Loss')
plt.legend()
plt.show()

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# Since this is a regression model we will be using mean squared error, mean absolute error and the r squared score to evaluate it.

# %%
# Calculate and print regression metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Mean Absolute Error (MAE): {mae:.4f}')
print(f'R² Score: {r2:.4f}')
# Out:
# Mean Squared Error (MSE): 41.9996
# Mean Absolute Error (MAE): 4.5933
# R² Score: 0.8448

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# For other models, other types of performance metrics are more meaningfull. It all depends on context and the end goal of the model.
#
# Research, planning and analysing various metrics with a clearly defined end goal is key to understanding how capable a model is and what are his limitations.
#
# Keep that in mind when tackling the next exercises!

# %% [markdown]
# ### Thank you for following this tutorial!
