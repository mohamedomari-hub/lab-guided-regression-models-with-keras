# %% [markdown]
# <h1> Guided lab: Regression Models with Keras</h1>
#
# Objective for this Notebook
#
# - How to use the Tensorflow API, Keras, to build a regression model.
# - Download and Clean dataset
# - Build a Neural Network
# - Train and Test the Network

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean Dataset</a>
# 2. <a href="#item32">Import Keras</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean Dataset

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have.

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ## Import Keras

# %% [markdown]
# Recall from the videos that Keras normally runs on top of a low-level library such as TensorFlow. This means that to be able to use the Keras library, you will have to install TensorFlow first and when you import the Keras library, it will be explicitly displayed what backend was used to install the Keras library. In CC Labs, we used TensorFlow as the backend to install Keras, so it should clearly print that when we import Keras.

# %% [markdown]
# #### Let's go ahead and import the Keras library

# %%
from tensorflow import keras

# %% [markdown]
# As you can see, the TensorFlow backend was used to install the Keras library.

# %% [markdown]
# Let's import the rest of the packages from the Keras library that we will need to build our regressoin model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model    
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# <a id='item34'></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()
# Out:
# /opt/anaconda3/envs/ironhack/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Now we will split our data into training and testing with a 70%-30% split (test_size=0.3).
#
# 70% of our data will be used for training :
#
# X_train : Our training data containing the variables the model will use to learn how to predict.
#
# y_train : Our training data containing the labels.
#
# #
# 30% of our data will be used for testing its performance metrics :
#
# X_test : Unseen data by the model, we will use it to make predictions with our trained model.
#
# y_test : The labels associated with X_test data, we will compare them with the predictions that our model provided as output when shown X_test and that way we will obtain performance metrics.

# %%
from sklearn.model_selection import train_test_split
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=42)

# %% [markdown]
# Next, we will train the model using the *fit* method. We will train the model for 100 epochs.

# %%
# fit the model
fit_model = model.fit(X_train, y_train, validation_split=0.2, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 18/18 - 1s - 48ms/step - loss: 1518.9127 - mae: 35.0995 - val_loss: 1478.4844 - val_mae: 35.1459
# Epoch 2/100
# 18/18 - 0s - 2ms/step - loss: 1348.6058 - mae: 32.6759 - val_loss: 1225.8392 - val_mae: 31.4754
# Epoch 3/100
# 18/18 - 0s - 2ms/step - loss: 980.2889 - mae: 26.7656 - val_loss: 723.2974 - val_mae: 22.8014
# Epoch 4/100
# 18/18 - 0s - 2ms/step - loss: 459.0025 - mae: 17.0786 - val_loss: 273.6458 - val_mae: 13.2223
# Epoch 5/100
# 18/18 - 0s - 2ms/step - loss: 268.7066 - mae: 13.2842 - val_loss: 195.8268 - val_mae: 11.4102
# Epoch 6/100
# 18/18 - 0s - 2ms/step - loss: 229.2253 - mae: 12.2477 - val_loss: 194.8369 - val_mae: 11.5815
# Epoch 7/100
# 18/18 - 0s - 2ms/step - loss: 213.7545 - mae: 11.8061 - val_loss: 186.4474 - val_mae: 11.3588
# Epoch 8/100
# 18/18 - 0s - 2ms/step - loss: 203.8939 - mae: 11.5949 - val_loss: 174.6325 - val_mae: 11.0827
# Epoch 9/100
# 18/18 - 0s - 2ms/step - loss: 194.4861 - mae: 11.2922 - val_loss: 167.6918 - val_mae: 10.8702
# Epoch 10/100
# 18/18 - 0s - 2ms/step - loss: 187.6588 - mae: 11.0757 - val_loss: 164.8054 - val_mae: 10.8019
# Epoch 11/100
# 18/18 - 0s - 2ms/step - loss: 179.8720 - mae: 10.8496 - val_loss: 163.3737 - val_mae: 10.7035
# Epoch 12/100
# 18/18 - 0s - 3ms/step - loss: 174.6054 - mae: 10.7175 - val_loss: 155.9813 - val_mae: 10.4723
# Epoch 13/100
# 18/18 - 0s - 2ms/step - loss: 169.0311 - mae: 10.5604 - val_loss: 155.3366 - val_mae: 10.4842
# Epoch 14/100
# 18/18 - 0s - 2ms/step - loss: 163.6475 - mae: 10.3641 - val_loss: 149.7442 - val_mae: 10.2754
# Epoch 15/100
# 18/18 - 0s - 2ms/step - loss: 159.6712 - mae: 10.2012 - val_loss: 148.6446 - val_mae: 10.2318
# Epoch 16/100
# 18/18 - 0s - 2ms/step - loss: 153.9338 - mae: 10.0397 - val_loss: 147.5890 - val_mae: 10.1991
# Epoch 17/100
# 18/18 - 0s - 2ms/step - loss: 150.5011 - mae: 9.9187 - val_loss: 146.5086 - val_mae: 10.1523
# Epoch 18/100
# 18/18 - 0s - 2ms/step - loss: 146.8711 - mae: 9.8252 - val_loss: 143.1072 - val_mae: 10.0095
# Epoch 19/100
# 18/18 - 0s - 2ms/step - loss: 143.1545 - mae: 9.6884 - val_loss: 140.7777 - val_mae: 9.9195
# Epoch 20/100
# 18/18 - 0s - 2ms/step - loss: 139.0678 - mae: 9.5552 - val_loss: 137.2204 - val_mae: 9.7822
# Epoch 21/100
# 18/18 - 0s - 2ms/step - loss: 136.0187 - mae: 9.4257 - val_loss: 134.7603 - val_mae: 9.6962
# Epoch 22/100
# 18/18 - 0s - 2ms/step - loss: 132.5933 - mae: 9.3123 - val_loss: 133.9597 - val_mae: 9.6427
# Epoch 23/100
# 18/18 - 0s - 2ms/step - loss: 129.3444 - mae: 9.1852 - val_loss: 133.8521 - val_mae: 9.6347
# Epoch 24/100
# 18/18 - 0s - 2ms/step - loss: 127.0340 - mae: 9.0907 - val_loss: 127.7996 - val_mae: 9.3658
# Epoch 25/100
# 18/18 - 0s - 2ms/step - loss: 122.7765 - mae: 8.9466 - val_loss: 129.1674 - val_mae: 9.4411
# Epoch 26/100
# 18/18 - 0s - 2ms/step - loss: 120.0925 - mae: 8.8406 - val_loss: 127.0659 - val_mae: 9.3547
# Epoch 27/100
# 18/18 - 0s - 2ms/step - loss: 118.0944 - mae: 8.8013 - val_loss: 120.7978 - val_mae: 9.0321
# Epoch 28/100
# 18/18 - 0s - 2ms/step - loss: 115.6183 - mae: 8.6477 - val_loss: 124.3103 - val_mae: 9.1935
# Epoch 29/100
# 18/18 - 0s - 2ms/step - loss: 109.7647 - mae: 8.4432 - val_loss: 119.1166 - val_mae: 8.9855
# Epoch 30/100
# 18/18 - 0s - 2ms/step - loss: 106.8351 - mae: 8.3234 - val_loss: 116.3337 - val_mae: 8.8329
# Epoch 31/100
# 18/18 - 0s - 2ms/step - loss: 103.4305 - mae: 8.1622 - val_loss: 114.7707 - val_mae: 8.8250
# Epoch 32/100
# 18/18 - 0s - 2ms/step - loss: 100.9263 - mae: 8.0478 - val_loss: 112.5583 - val_mae: 8.7145
# Epoch 33/100
# 18/18 - 0s - 2ms/step - loss: 97.6635 - mae: 7.8965 - val_loss: 108.5108 - val_mae: 8.4846
# Epoch 34/100
# 18/18 - 0s - 2ms/step - loss: 94.0715 - mae: 7.7494 - val_loss: 105.0752 - val_mae: 8.3496
# Epoch 35/100
# 18/18 - 0s - 2ms/step - loss: 90.5723 - mae: 7.5887 - val_loss: 103.3319 - val_mae: 8.2724
# Epoch 36/100
# 18/18 - 0s - 2ms/step - loss: 87.1613 - mae: 7.4289 - val_loss: 100.7929 - val_mae: 8.1743
# Epoch 37/100
# 18/18 - 0s - 2ms/step - loss: 83.4536 - mae: 7.2452 - val_loss: 93.9738 - val_mae: 7.7958
# Epoch 38/100
# 18/18 - 0s - 2ms/step - loss: 80.0623 - mae: 7.0887 - val_loss: 94.1537 - val_mae: 7.8348
# Epoch 39/100
# 18/18 - 0s - 2ms/step - loss: 77.2841 - mae: 6.9242 - val_loss: 91.6357 - val_mae: 7.6896
# Epoch 40/100
# 18/18 - 0s - 2ms/step - loss: 74.7767 - mae: 6.8304 - val_loss: 84.0459 - val_mae: 7.2734
# Epoch 41/100
# 18/18 - 0s - 2ms/step - loss: 72.6573 - mae: 6.6963 - val_loss: 88.0119 - val_mae: 7.5402
# Epoch 42/100
# 18/18 - 0s - 2ms/step - loss: 68.8801 - mae: 6.4926 - val_loss: 81.3657 - val_mae: 7.1603
# Epoch 43/100
# 18/18 - 0s - 2ms/step - loss: 66.8369 - mae: 6.4192 - val_loss: 77.4034 - val_mae: 6.8957
# Epoch 44/100
# 18/18 - 0s - 6ms/step - loss: 64.2491 - mae: 6.2487 - val_loss: 78.7250 - val_mae: 6.9869
# Epoch 45/100
# 18/18 - 0s - 2ms/step - loss: 61.1972 - mae: 6.0378 - val_loss: 73.2973 - val_mae: 6.6636
# Epoch 46/100
# 18/18 - 0s - 3ms/step - loss: 59.0564 - mae: 5.9389 - val_loss: 72.9020 - val_mae: 6.6796
# Epoch 47/100
# 18/18 - 0s - 3ms/step - loss: 57.8540 - mae: 5.8846 - val_loss: 72.3789 - val_mae: 6.6142
# Epoch 48/100
# 18/18 - 0s - 3ms/step - loss: 55.9824 - mae: 5.7527 - val_loss: 69.9011 - val_mae: 6.4885
# Epoch 49/100
# 18/18 - 0s - 3ms/step - loss: 53.9589 - mae: 5.6366 - val_loss: 64.8012 - val_mae: 6.2494
# Epoch 50/100
# 18/18 - 0s - 3ms/step - loss: 53.6741 - mae: 5.7342 - val_loss: 75.1875 - val_mae: 6.8456
# Epoch 51/100
# 18/18 - 0s - 3ms/step - loss: 53.4185 - mae: 5.6113 - val_loss: 63.9520 - val_mae: 6.1876
# Epoch 52/100
# 18/18 - 0s - 3ms/step - loss: 50.2463 - mae: 5.4459 - val_loss: 60.8816 - val_mae: 6.0263
# Epoch 53/100
# 18/18 - 0s - 3ms/step - loss: 48.9747 - mae: 5.3851 - val_loss: 59.1163 - val_mae: 5.9290
# Epoch 54/100
# 18/18 - 0s - 3ms/step - loss: 47.1343 - mae: 5.2730 - val_loss: 60.1265 - val_mae: 6.0066
# Epoch 55/100
# 18/18 - 0s - 3ms/step - loss: 46.0252 - mae: 5.1845 - val_loss: 58.9373 - val_mae: 5.9635
# Epoch 56/100
# 18/18 - 0s - 3ms/step - loss: 45.1152 - mae: 5.1379 - val_loss: 57.2343 - val_mae: 5.8686
# Epoch 57/100
# 18/18 - 0s - 3ms/step - loss: 44.3363 - mae: 5.1144 - val_loss: 56.4440 - val_mae: 5.8431
# Epoch 58/100
# 18/18 - 0s - 3ms/step - loss: 43.2277 - mae: 5.0260 - val_loss: 54.4764 - val_mae: 5.7254
# Epoch 59/100
# 18/18 - 0s - 3ms/step - loss: 42.2041 - mae: 4.9353 - val_loss: 50.8337 - val_mae: 5.4632
# Epoch 60/100
# 18/18 - 0s - 3ms/step - loss: 41.7673 - mae: 4.9384 - val_loss: 52.5887 - val_mae: 5.5330
# Epoch 61/100
# 18/18 - 0s - 3ms/step - loss: 40.8847 - mae: 4.9193 - val_loss: 51.3696 - val_mae: 5.5407
# Epoch 62/100
# 18/18 - 0s - 3ms/step - loss: 38.5028 - mae: 4.7162 - val_loss: 50.2195 - val_mae: 5.4693
# Epoch 63/100
# 18/18 - 0s - 3ms/step - loss: 38.6224 - mae: 4.7103 - val_loss: 49.4115 - val_mae: 5.4017
# Epoch 64/100
# 18/18 - 0s - 2ms/step - loss: 37.2553 - mae: 4.6615 - val_loss: 49.9944 - val_mae: 5.4080
# Epoch 65/100
# 18/18 - 0s - 2ms/step - loss: 36.3761 - mae: 4.5661 - val_loss: 48.4808 - val_mae: 5.3341
# Epoch 66/100
# 18/18 - 0s - 3ms/step - loss: 35.3848 - mae: 4.4867 - val_loss: 45.9041 - val_mae: 5.1767
# Epoch 67/100
# 18/18 - 0s - 3ms/step - loss: 35.7546 - mae: 4.5108 - val_loss: 46.2481 - val_mae: 5.1825
# Epoch 68/100
# 18/18 - 0s - 2ms/step - loss: 35.3686 - mae: 4.5211 - val_loss: 45.1760 - val_mae: 5.1164
# Epoch 69/100
# 18/18 - 0s - 2ms/step - loss: 34.9340 - mae: 4.4441 - val_loss: 47.3596 - val_mae: 5.2483
# Epoch 70/100
# 18/18 - 0s - 3ms/step - loss: 32.6772 - mae: 4.3180 - val_loss: 45.5629 - val_mae: 5.1341
# Epoch 71/100
# 18/18 - 0s - 3ms/step - loss: 31.7256 - mae: 4.2438 - val_loss: 43.0307 - val_mae: 4.9586
# Epoch 72/100
# 18/18 - 0s - 2ms/step - loss: 32.1326 - mae: 4.2779 - val_loss: 43.5457 - val_mae: 5.0016
# Epoch 73/100
# 18/18 - 0s - 2ms/step - loss: 30.7435 - mae: 4.1969 - val_loss: 43.8517 - val_mae: 5.0388
# Epoch 74/100
# 18/18 - 0s - 2ms/step - loss: 30.5672 - mae: 4.1598 - val_loss: 41.4176 - val_mae: 4.8521
# Epoch 75/100
# 18/18 - 0s - 2ms/step - loss: 30.9210 - mae: 4.2067 - val_loss: 41.0192 - val_mae: 4.8243
# Epoch 76/100
# 18/18 - 0s - 2ms/step - loss: 29.4102 - mae: 4.0997 - val_loss: 42.2671 - val_mae: 4.9147
# Epoch 77/100
# 18/18 - 0s - 5ms/step - loss: 29.0337 - mae: 4.0912 - val_loss: 42.0852 - val_mae: 4.9262
# Epoch 78/100
# 18/18 - 0s - 2ms/step - loss: 28.4014 - mae: 4.0414 - val_loss: 41.4217 - val_mae: 4.8763
# Epoch 79/100
# 18/18 - 0s - 2ms/step - loss: 28.4029 - mae: 4.0297 - val_loss: 40.4337 - val_mae: 4.8376
# Epoch 80/100
# 18/18 - 0s - 2ms/step - loss: 27.5885 - mae: 3.9181 - val_loss: 39.9327 - val_mae: 4.7402
# Epoch 81/100
# 18/18 - 0s - 2ms/step - loss: 27.5589 - mae: 3.9644 - val_loss: 40.1454 - val_mae: 4.8428
# Epoch 82/100
# 18/18 - 0s - 2ms/step - loss: 26.6237 - mae: 3.8942 - val_loss: 38.4925 - val_mae: 4.6669
# Epoch 83/100
# 18/18 - 0s - 2ms/step - loss: 26.8335 - mae: 3.8895 - val_loss: 41.4999 - val_mae: 4.8601
# Epoch 84/100
# 18/18 - 0s - 2ms/step - loss: 26.4444 - mae: 3.8354 - val_loss: 38.3725 - val_mae: 4.6408
# Epoch 85/100
# 18/18 - 0s - 3ms/step - loss: 25.1529 - mae: 3.7527 - val_loss: 37.2780 - val_mae: 4.5873
# Epoch 86/100
# 18/18 - 0s - 3ms/step - loss: 24.6347 - mae: 3.7380 - val_loss: 39.5166 - val_mae: 4.7425
# Epoch 87/100
# 18/18 - 0s - 2ms/step - loss: 24.3459 - mae: 3.6901 - val_loss: 37.9090 - val_mae: 4.6222
# Epoch 88/100
# 18/18 - 0s - 3ms/step - loss: 25.0360 - mae: 3.8032 - val_loss: 40.4663 - val_mae: 4.7872
# Epoch 89/100
# 18/18 - 0s - 2ms/step - loss: 25.8964 - mae: 3.7958 - val_loss: 40.5741 - val_mae: 4.8298
# Epoch 90/100
# 18/18 - 0s - 3ms/step - loss: 25.0005 - mae: 3.7720 - val_loss: 37.3743 - val_mae: 4.6313
# Epoch 91/100
# 18/18 - 0s - 3ms/step - loss: 24.1318 - mae: 3.6826 - val_loss: 36.0494 - val_mae: 4.5006
# Epoch 92/100
# 18/18 - 0s - 3ms/step - loss: 22.8957 - mae: 3.5485 - val_loss: 39.0251 - val_mae: 4.7194
# Epoch 93/100
# 18/18 - 0s - 3ms/step - loss: 22.7974 - mae: 3.6295 - val_loss: 37.7886 - val_mae: 4.6469
# Epoch 94/100
# 18/18 - 0s - 3ms/step - loss: 22.9525 - mae: 3.5476 - val_loss: 37.4762 - val_mae: 4.6302
# Epoch 95/100
# 18/18 - 0s - 3ms/step - loss: 22.1424 - mae: 3.5579 - val_loss: 34.8134 - val_mae: 4.4330
# Epoch 96/100
# 18/18 - 0s - 3ms/step - loss: 21.6061 - mae: 3.5083 - val_loss: 38.7257 - val_mae: 4.6991
# Epoch 97/100
# 18/18 - 0s - 2ms/step - loss: 21.6366 - mae: 3.4591 - val_loss: 34.5902 - val_mae: 4.4491
# Epoch 98/100
# 18/18 - 0s - 2ms/step - loss: 21.7142 - mae: 3.5308 - val_loss: 35.7197 - val_mae: 4.5210
# Epoch 99/100
# 18/18 - 0s - 2ms/step - loss: 21.4184 - mae: 3.4740 - val_loss: 34.9364 - val_mae: 4.4242
# Epoch 100/100
# 18/18 - 0s - 2ms/step - loss: 21.3342 - mae: 3.4741 - val_loss: 35.3220 - val_mae: 4.4340

# %% [markdown]
# ### Now lets evaluate our model and get performance metrics !
#
# First, since our model only saw the training data and learned from it, we will make predictions on the unseen test set.
#
# y_pred are the predictions that our model generated from it's experience when shown the predictor variables of X_test.
#
# That way we can compare y_pred (predictions made by our model) with y_test (the real labels of X_test) and see the difference as performance metrics.

# %%
import matplotlib.pyplot as plt

plt.plot(fit_model.history['loss'], label='Training Loss')
plt.plot(fit_model.history['val_loss'], label='Validation Loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss vs Validation Loss')
plt.legend()
plt.show()

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# Since this is a regression model we will be using mean squared error, mean absolute error and the r squared score to evaluate it.

# %%
# Calculate and print regression metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Mean Absolute Error (MAE): {mae:.4f}')
print(f'R² Score: {r2:.4f}')
# Out:
# Mean Squared Error (MSE): 40.5104
# Mean Absolute Error (MAE): 4.7770
# R² Score: 0.8503

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# For other models, other types of performance metrics are more meaningfull. It all depends on context and the end goal of the model.
#
# Research, planning and analysing various metrics with a clearly defined end goal is key to understanding how capable a model is and what are his limitations.
#
# Keep that in mind when tackling the next exercises!

# %% [markdown]
# ### Thank you for following this tutorial!
